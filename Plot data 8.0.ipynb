# %%
# %matplotlib notebook
import sys 
import os

import matplotlib as mpl

import numpy as np
from IPython.display import Math
import matplotlib.pyplot as plt
import importlib
import scipy as sci
from scipy import stats
from scipy.signal import savgol_filter
from scipy import signal

import analysis as a #my analysis source

title_font=14
axes_font=14
tick_font=14
marker_size=6
text_font=16
caption_font=18
legend_font = 10

sub_hspace=8    
sub_wspace=1

#mpl.rcParams['figure.dpi'] = 100 #dpi

G_0 = 7.74809173e10-5
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-33a519e5ab9d> in <module>()
#      31 G_0 = 7.74809173e10-5
#      32
# ---> 33 importlib.reload(a)   #run this when modifications are done on 'analysis.py'
#
# C:\ProgramData\Anaconda3\lib\importlib\__init__.py in reload(module)
#     164         target = module
#     165         spec = module.__spec__ = _bootstrap._find_spec(name, pkgpath, target)
# --> 166         _bootstrap._exec(spec, module)
#     167         # The module may have replaced itself in sys.modules!
#     168         return sys.modules[name]
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in _exec(spec, module)
#
# AttributeError: 'NoneType' object has no attribute 'name'

# %%
os.chdir(r'D:\pycharmprojects\insects\PhD') 
importlib.reload(a)
# Out:
# <module 'analysis' from 'D:\\pycharmprojects\\insects\\PhD\\analysis.py'>

# %%
os.chdir(r"D:\pycharmprojects\insects\data")  #  folder where the data lies.
   #run this when modifications are done on 'analysis.py'

# %%
inputFile = 'device1_4940.txt'
col_x = 2
conversion_x = 1
label_x = ' $PG fine$ '

col_y = 0
conversion_y = 1
label_y = '  $ B_{perp}$ (T)'

col_z = 7
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [0.73],
                   vertical_linecuts = [400],
                   x_lims =False,
                   y_lims =False,
                    color_min = 0.05, color_max = 0.55
         );
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
inputFile = 'data\device1_4956.txt'
col_x = 2
conversion_x = 1
label_x = ' $PG fine$ '

col_y = 0
conversion_y = 1
label_y = '  $ B_{perp}$ (T)'

col_z = 7
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [1.4],
                   vertical_linecuts = [400],
                   x_lims =False,
                   y_lims =False,
                    color_min =0.1, color_max = 0.6
         );
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
inputFile = 'device1_4959.txt'

col_x = 1
conversion_x = 1
label_x = ' $PG fine$ '

col_y = 0
conversion_y = 1
label_y = '   TG 1 fine'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [1.4],
                   vertical_linecuts = [400],
                   x_lims =False,
                   y_lims =False,
                    color_min =0.03, color_max = 0.25
         );
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
inputFile = 'device1_4960.txt'

col_x = 1
conversion_x = 1
label_x = ' $PG fine$ '

col_y = 0
conversion_y = 1
label_y = '   TG 1 fine'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [100],
                   vertical_linecuts = [400],
                   x_lims =False,
                   y_lims =[0, 500],
                    color_min =0.03, color_max = 0.20
         );
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
inputFile = 'device1_4961.txt'

col_x = 1
conversion_x = 1
label_x = ' $PG fine$ '

col_y = 0
conversion_y = 1
label_y = '   TG 1 fine'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [450],
                   vertical_linecuts = [400],
                   x_lims =False,
                   y_lims =[0, 500],
                    color_min =0.03, color_max = 0.20
         );
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
inputFile = 'device1_4968.txt'

col_x = 1
conversion_x = 1
label_x = ' $PG fine$ '

col_y = 0
conversion_y = 1
label_y = '   TG 1 fine'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [450],
                   vertical_linecuts = [400],
                   x_lims =False,
                   y_lims =[0, 500],
                    color_min =0.03, color_max = 0.20
         );
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(figsize=(4, 2))

filename = 'device1_4967.txt'
gate, G = a.extract(filename, 1, 6)[0], a.extract(filename, 1, 6)[1]
plt.plot(gate, G , label = filename, linestyle =  '-')
plt.xlabel('PG fine (with TG1 compensed)')
plt.tight_layout()

fig = plt.figure(figsize=(4, 2))

gate, G = a.extract(filename, 0, 6)[0], a.extract(filename, 0, 6)[1]
plt.plot(gate, G , label = filename, linestyle =  '-')
plt.xlabel('TG1 fine (with PG compensed)')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="400">
