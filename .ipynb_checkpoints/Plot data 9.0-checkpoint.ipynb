# %%
import sys 
import os
import matplotlib as mpl
import numpy as np
from IPython.display import Math
import matplotlib.pyplot as plt
import importlib
import scipy as sci
from scipy import stats
from scipy.signal import savgol_filter
from scipy import signal
import analysis as a #my analysis source
import pylab
import time
#%pylab inline
pylab.rcParams['figure.figsize'] = (4, 3)
pylab.rcParams['font.size'] = 10
pylab.rcParams['font.family'] = 'Arial'
title_font=14
axes_font=14
tick_font=14
marker_size=6
text_font=16
caption_font=18
legend_font = 10
sub_hspace=8    
sub_wspace=1
plt.rcParams['figure.dpi'] = 100 #dpi
G_0 = 7.74809173e10-5
# %matplotlib notebook

# %%
os.chdir(r'D:\pycharmprojects\insects\PhD') 
importlib.reload(a)  #run this when modifications are done on 'analysis.py'
os.chdir(r"D:\pycharmprojects\insects\data")  #  folder where the data lies.

# %%
fig = plt.figure(figsize=(4, 2))

filename = 'device1_7036.txt'
gate, G = a.extract(filename, 0, 1)
plt.plot(gate, G , label = filename, linestyle =  '-')

filename = 'device1_7037.txt'
gate, G = a.extract(filename, 0, 1)
plt.plot(gate, G , label = filename, linestyle =  '-')


plt.xlabel('TG2 (dac9)')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="398.88889945583605">

# %%
inputFile = 'device1_7051.txt'
col_x = 1
conversion_x = 1
label_x = ' $TG2 dac9 $ '

col_y = 0
conversion_y = 1
label_y = '  $ TG1 dac11 $'

col_z = 2
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[(-500, -1400)],
                   horizontal_linecuts = [-1000],
                   vertical_linecuts = [-400],
                   x_lims = False,
                   y_lims = False,
                    color_min = 0.04, color_max = 0.5
         );
# Out:
# <img src="data:image/png;base64,..." width="600">
# First point at: -500 , -1400

# %%
inputFile = 'device1_7069.txt'
col_x = 1
conversion_x = 1
label_x = ' $TG2 dac9 $ '

col_y = 0
conversion_y = 1
label_y = '  $ TG1 dac11 $'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [-1700],
                   vertical_linecuts = [-400],
                   x_lims = False,
                   y_lims = False,
                    color_min = 0.01, color_max = 0.5
         );
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#From now on looking at the noise source.
#

# %%
# RG scan
fig = plt.figure(figsize=(6, 5))

filename = 'device1_7072.txt'
gate, G = a.extract(filename, 0, 1)
plt.plot(gate, G , label = filename + 'f = 23 Hz', linestyle =  '-')

filename = 'device1_7074.txt'
gate, G = a.extract(filename, 0, 1)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')

filename = 'device1_7075.txt'
gate, G = a.extract(filename, 0, 1)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')

plt.legend(loc= 0 )
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# looks like the frequency 77.89 has less noise than 23 Hz

# %%
#TG1 scan

fig = plt.figure(figsize=(6, 5))


filename = 'device1_7076.txt'
gate, G = a.extract(filename, 0, 1)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')

filename = 'device1_7077.txt'
gate, G = a.extract(filename, 0, 1)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')

plt.xlabel('TG1')

plt.legend(loc= 0 )
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#TG2 scan

fig = plt.figure(figsize=(6, 5))


filename = 'device1_7078.txt'
gate, G = a.extract(filename, 0, 5)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')

filename = 'device1_7079.txt'
gate, G = a.extract(filename, 0, 5)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')




plt.xlabel('TG2')

plt.legend(loc= 0 )
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#PG scan

fig = plt.figure(figsize=(6, 5))


filename = 'device1_7080.txt'
gate, G = a.extract(filename, 0, 5)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')

filename = 'device1_7081.txt'
gate, G = a.extract(filename, 0, 5)
plt.plot(gate, G  , label = filename + 'f = 77.89 Hz' , linestyle =  '-')




plt.xlabel('PG')

plt.legend(loc= 0 )
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
inputFile = 'device1_7082.txt'

col_x = 1
conversion_x = 1
label_x = ' $TG2 $ '

col_y = 0
conversion_y = 1
label_y = '  $ TG1 $'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[(-600, -1900)],
                   horizontal_linecuts = [-1700],
                   vertical_linecuts = [-400],
                   x_lims = False,
                   y_lims = False,
                    color_min = 0.01, color_max = 0.5
         );
# Out:
# <img src="data:image/png;base64,..." width="600">
# First point at: -600 , -1900

# %%
inputFile = 'device1_7087.txt'

col_x = 1
conversion_x = 1
label_x = ' $TG2 $ '

col_y = 0
conversion_y = 1
label_y = '  $ TG1 $'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [-1700],
                   vertical_linecuts = [-400],
                   x_lims = False,
                   y_lims = False,
                    color_min = 0.01, color_max = 0.5
         );
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
inputFile = 'device1_7088.txt'

col_x = 1
conversion_x = 1
label_x = ' $TG2 $ '

col_y = 0
conversion_y = 1
label_y = '  $ TG1 $'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [-1700],
                   vertical_linecuts = [-400],
                   x_lims = False,
                   y_lims = False,
                    color_min = 0.01, color_max = 0.5
         );
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
inputFile = 'device1_7097.txt'

col_x = 1
conversion_x = 1
label_x = ' $TG2 $ '

col_y = 0
conversion_y = 1
label_y = '  $ TG1 $'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [-1700],
                   vertical_linecuts = [-400],
                   x_lims = False,
                   y_lims = False,
                    color_min = 0.01, color_max = 0.5
         );
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
inputFile = 'device1_7103.txt'

col_x = 1
conversion_x = 1
label_x = ' $TG2 $ '

col_y = 0
conversion_y = 1
label_y = '  $ TG1 $'

col_z = 6
label_z = '  G $ (2e^2 /h) $'
conversion_z = 1 

plot_name = ''

a.colorplot_special(inputFile, 
                   col_x, label_x, conversion_x, 
                   col_y, label_y, conversion_y, 
                   col_z, label_z, conversion_z, 
                   plot_name,  points_list =[],
                   horizontal_linecuts = [-1700],
                   vertical_linecuts = [-400],
                   x_lims = False,
                   y_lims = False,
                    color_min = 0.01, color_max = 0.5
         );
# Out:
# <img src="data:image/png;base64,..." width="600">
